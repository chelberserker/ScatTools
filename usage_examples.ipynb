# %%
from src import calculate_cell_parameters, calculate_q_values

# %%
example_qxy1 = 0.934998
example_qxy2 = 1.308997
example_qxy3 = 1.379241
example_qz1 = 0.431857
example_qz2 = 0.604600
example_qz3 = 0.172743
cell_parameters = calculate_cell_parameters(example_qxy1, example_qxy2, example_qxy3, example_qz1, example_qz2, example_qz3)

# %%
for param in cell_parameters:
    print(f"{param} = {cell_parameters[param]}")
# Out:
# a = 7.0
# b = 5.0
# gamma = 73.74
# tilt = 30.0
# azimuth = -53.13
# area = 33.6

# %%
q_vectors = calculate_q_values(7, 5, 73.74, 30, -53.13)

# %%
for param in q_vectors:
    print(f"{param} = {q_vectors[param]}")
# Out:
# qxy1 = 0.935
# qz1 = 0.43186
# qxy2 = 1.309
# qz2 = 0.26603
# qxy3 = 1.37924
# qz3 = 0.69788
